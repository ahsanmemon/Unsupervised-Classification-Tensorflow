# %%
from PIL import Image, ImageEnhance, ImageOps
import numpy as np
import random
import matplotlib.pyplot as plt
from scipy import ndimage

from scan_tf.utils import augmentations
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-042eee16bb3e> in <module>
#       5 from scipy import ndimage
#       6
# ----> 7 from scan_tf.utils import augmentations
#
# ModuleNotFoundError: No module named 'scan_tf'

# %%
# Pick random transformation function:
augmentation_name = np.random.choice(list(func.keys()))
p = np.random.uniform(strong_augment_bounds[augmentation_name][0], strong_augment_bounds[augmentation_name][1])
print(augmentation_name, p)
im = Image.open(r"D:\Personal\AutoAugment-master\AutoAugment-master\images/im_0001.png")
plt.imshow(im)
# Out:
# autocontrast 0.651165348667013

# %%
f, axarr = plt.subplots(4, 4, figsize=(15, 15), gridspec_kw={"wspace": 0, "hspace": 0})
for idx, ax in enumerate(f.axes):
    augmentation_name = np.random.choice(list(func_pil.keys()))
    p = np.random.uniform(strong_augment_bounds[augmentation_name][0], strong_augment_bounds[augmentation_name][1])
    title = f"{augmentation_name} ({p:.2f})"
    augmented_im = func_pil[augmentation_name](im, p)
    ax.imshow(augmented_im)
    ax.axis("off")
    ax.set_title(title)
plt.show()

# %%
# Strong data augmentation
f, axarr = plt.subplots(4, 4, figsize=(15, 15), gridspec_kw={"wspace": 0, "hspace": 0})
for idx, ax in enumerate(f.axes):
    augmented_im = strong_augmentation(im)
    ax.imshow(augmented_im)
    ax.axis("off")
plt.show()
